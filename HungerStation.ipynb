# %% [markdown]
# # Hungerstation twitter data (using API)

# %% [markdown]
# This project aims to build dataset about largest saudi telecom comanies (STC, Mobily and Zain) which collected from social media especially Twitter.

# %%
# !pip install tweepy

# %%
pip install jsonpickle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
import tweepy 
import pandas as pd
import re
import jsonpickle

# %%
CONSUMER_KEY = '----' 
CONSUMER_SECRET = '----'
ACCESS_TOKEN = '----'
ACCESS_SECRET = '----'

# Setup access API
def connect_to_twitter_OAuth():
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    
    api = tweepy.API(auth)
    return api
 
# Create API object
api = connect_to_twitter_OAuth()

# %% [markdown]
# # Hungerstaion

# %%
# =============
# search words will be #"HungerStation" & "هنقرستيشن"


query = 'هنقرستيشن'
max_tweets = 10000 #number of maximum allowed tweets
lang= 'ar'
tweetCount = 0

tweet_list = []


for tweet in tweepy.Cursor(api.search,q=query,lang=lang).items(max_tweets):         

    #Convert to JSON format
    tweettosave = jsonpickle.encode(tweet._json, unpicklable=False).encode('utf-8')
    tweet_list.append(tweettosave)

    tweetCount += 1

    #Display how many tweets we have collected
    print("Downloaded {0} tweets".format(tweetCount))
# Out:
# Downloaded 1 tweets
# Downloaded 2 tweets
# Downloaded 3 tweets
# Downloaded 4 tweets
# Downloaded 5 tweets
# Downloaded 6 tweets
# Downloaded 7 tweets
# Downloaded 8 tweets
# Downloaded 9 tweets
# Downloaded 10 tweets
# Downloaded 11 tweets
# Downloaded 12 tweets
# Downloaded 13 tweets
# Downloaded 14 tweets
# Downloaded 15 tweets
# Downloaded 16 tweets
# Downloaded 17 tweets
# Downloaded 18 tweets
# Downloaded 19 tweets
# Downloaded 20 tweets
# Downloaded 21 tweets
# Downloaded 22 tweets
# Downloaded 23 tweets
# Downloaded 24 tweets
# Downloaded 25 tweets
# Downloaded 26 tweets
# Downloaded 27 tweets
# Downloaded 28 tweets
# Downloaded 29 tweets
# Downloaded 30 tweets
# Downloaded 31 tweets
# Downloaded 32 tweets
# Downloaded 33 tweets
# Downloaded 34 tweets
# Downloaded 35 tweets
# Downloaded 36 tweets
# Downloaded 37 tweets
# Downloaded 38 tweets
# Downloaded 39 tweets
# Downloaded 40 tweets
# Downloaded 41 tweets
# Downloaded 42 tweets
# Downloaded 43 tweets
# ...

# %%
tweet_list[0:2]
# Out:
# [b'{"contributors": null, "coordinates": null, "created_at": "Wed Aug 07 07:48:09 +0000 2019", "entities": {"hashtags": [], "symbols": [], "urls": [], "user_mentions": [{"id": 548429962, "id_str": "548429962", "indices": [0, 14], "name": "HungerStation | \\u0647\\u0646\\u0642\\u0631\\u0633\\u062a\\u064a\\u0634\\u0646", "screen_name": "HungerStation"}]}, "favorite_count": 0, "favorited": false, "geo": null, "id": 1159008310101729280, "id_str": "1159008310101729280", "in_reply_to_screen_name": "HungerStation", "in_reply_to_status_id": 1159006707504336896, "in_reply_to_status_id_str": "1159006707504336896", "in_reply_to_user_id": 548429962, "in_reply_to_user_id_str": "548429962", "is_quote_status": false, "lang": "ar", "metadata": {"iso_language_code": "ar", "result_type": "recent"}, "place": null, "retweet_count": 0, "retweeted": false, "source": "<a href=\\"http://twitter.com/download/iphone\\" rel=\\"nofollow\\">Twitter for iPhone</a>", "text": "@HungerStation \\u0627\\u0644\\u0633\\
# ...

# %%
def tweets_to_df(tweets):
    
   
    
    text = []
    weekday = []
    month = []
    day = []
    hour = []
    hashtag = []
    url = []
    favorite = []
    reply = []
    retweet = []
    follower = []
    following = []
    user = []
    screen_name = []

    for t in tweets:
        t = jsonpickle.decode(t)
        
        # Text
        text.append(t['text'])
        
        # Decompose date
        date = t['created_at']
        weekday.append(date.split(' ')[0])
        month.append(date.split(' ')[1])
        day.append(date.split(' ')[2])
        
        time = date.split(' ')[3].split(':')
        hour.append(time[0]) 
        
        # Has hashtag
        if len(t['entities']['hashtags']) == 0:
            hashtag.append(0)
        else:
            hashtag.append(1)
            
        # Has url
        if len(t['entities']['urls']) == 0:
            url.append(0)
        else:
            url.append(1)
            
        # Number of favs
        favorite.append(t['favorite_count'])
        
        # Is it a reply?
        if t['in_reply_to_status_id'] == None:
            reply.append(0)
        else:
            reply.append(1)       
        
        # Retweets count
        retweet.append(t['retweet_count'])
        
        # Followers number
        follower.append(t['user']['followers_count'])
        
        # Following number
        following.append(t['user']['friends_count'])
        
        # Add user
        user.append(t['user']['name'])

        # Add screen name
        screen_name.append(t['user']['screen_name'])
        
    d = {'text': text,
         'weekday': weekday,
         'month' : month,
         'day': day,
         'hour' : hour,
         'has_hashtag': hashtag,
         'has_url': url,
         'fav_count': favorite,
         'is_reply': reply,
         'retweet_count': retweet,
         'followers': follower,
         'following' : following,
         'user': user,
         'screen_name' : screen_name
        }
    
    return pd.DataFrame(data = d)

# %%
tweets_df = tweets_to_df(tweet_list)

# %%
#Preprocessing del RT @blablabla:
tweets = tweets_df

# %%
tweets['tweetos'] = '' 

#add tweetos first part
for i in range(len(tweets['text'])):
    try:
        tweets['tweetos'][i] = tweets['text'].str.split(' ')[i][0]
    except AttributeError:    
        tweets['tweetos'][i] = 'other'

#Preprocessing tweetos. select tweetos contains 'RT @'
for i in range(len(tweets['text'])):
    if tweets['tweetos'].str.contains('@')[i]  == False:
        tweets['tweetos'][i] = 'other'
        
# remove URLs, RTs, and twitter handles
for i in range(len(tweets['text'])):
    tweets['text'][i] = " ".join([word for word in tweets['text'][i].split()
                                if 'http' not in word and '@' not in word and '<' not in word])


tweets['text'][1]
# Out:
# /Users/Abubattal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/Abubattal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /Users/Abubattal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 'RT كود هنقرستيشن 💞💞'

# %%
tweets['text'] = tweets['text'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', x.lower()))
tweets['text'] = tweets['text'].apply(lambda x: re.sub('  ', ' ', x))
tweets['text'][1]
# Out:
# 'rt كود هنقرستيشن 💞💞'

# %%
tweets.head()
# Out:
#                                                 text weekday month day hour  \
# 0  السلام عليكم، اخوي انا قدمت في هنقرستيشن كمندو...     Wed   Aug  07   07
# 1                                rt كود هنقرستيشن 💞💞     Wed   Aug  07   07
# 2  هنقرستيشن افضل تطبيق توصيل عيبهم الوحيد مايوفر...     Wed   Aug  07   07
# 3  التوصيل في مدينة جدة عن طريق تطبيق هنقرستيشن و...     Wed   Aug  07   07
# 4  كود هنقرستيشن للأرقام الجديده يرجعلك 50% من قي...     Wed   Aug  07   07
#
#    has_hashtag  has_url  fav_count  is_reply  retweet_count  followers  \
# 0            0        0          0         1              0         17
# 1            0        0          0         0              1        193
# 2            1        0          0         0              0       2341
# 3            0        0          0         1              0      42079
# 4            0        1          0         0              0         38
#
#    following                                      user screen_name  \
# ...

# %%
# tweets.to_csv('HungerStation.csv')
tweets.to_csv('هنقرستيشن.csv')
# we change the name of the file for each new used query (search word)

# %%
df = pd.read_csv('هنقرستيشن.csv')
df.shape
# Out:
# (2544, 16)
